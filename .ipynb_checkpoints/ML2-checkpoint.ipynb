# %% [markdown]
# ##### PARTICIPANTES
# - PABLO GARCIA MOLINA
# - ANDRES MARTINEZ FUENTES
# - JAVIER RIOS MONTES

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV

from sklearn import svm, neighbors, tree, linear_model
from sklearn.ensemble import BaggingRegressor

from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
# DATA EXTRACTION
train_df = pd.read_csv('data/TRAIN_DATA.csv', sep=';', encoding='utf_8')
final_test_df = pd.read_csv('data/TEST_INPUT.csv', sep=';', encoding='utf_8')

# %%
# SPLIT DATA
# Data is already sepparated between train and test sets
# but we are not provided with the testing results thus we wont use them for testing the models, only to provide final results 
# that will later be checked. Therefore, split in the train data is still needed.

features = list(train_df.columns)
target = 'WG'
features.remove(target)

X = train_df[features]
y = train_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,  
                                                    random_state=0,)

# %%
# PREPROCESSING
# We only work with numerical features this time

numerical_features = X_train.select_dtypes(include=['float64', 'int']).columns.to_list()
numerical_transformer = Pipeline(
    steps = [
        ("scaler", StandardScaler()),
        ("missing_values", SimpleImputer(strategy="mean")),
    ])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numerical_transformer, numerical_features),
],
    remainder='passthrough'
)

# %%
# REGRESSION MODELS WITH PIPELINE UNION
SLR = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", linear_model.LinearRegression())]
)

SV = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", svm.SVR())]
)

Kneighbors = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", neighbors.KNeighborsRegressor())]
)

Tree = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", tree.DecisionTreeRegressor())]
)

BR = Pipeline(
    steps=[("preprocessor", preprocessor), ("regressor", BaggingRegressor())]
)

# %%
# PARAM GRID FOR TWO HYPERPARAMETERS

SLR_param_grid = {
    'regressor__positive': [True, False]
}

SV_param_grid = {
    'regressor__kernel' : ['linear', 'rbf', 'sigmoid'],
    'regressor__C' : [1,5,10],
    'regressor__gamma': [0.001, 0.01, 1]
}

KN_param_grid = {
    'regressor__n_neighbors': [2,3,5,7,10],
}

Tree_param_grid = {
    'regressor__splitter': ['best','random'],
    'regressor__max_depth': [3,5,7,8],
    'regressor__min_samples_leaf': [1,5,10]
}

BR_param_grid = {
    'regressor__n_estimators': [5, 10, 15],
    'regressor__max_samples': [0.4, 0.5, 0.6],
    'regressor__max_features': [0.3, 0.4, 0.5],
    'regressor__bootstrap': [True, False],
    'regressor__bootstrap_features': [True, False]
}

# %%
# CREATTING DE GRIDS FOR EVERY MODEL

SLR_search = GridSearchCV(estimator = SLR, 
                      param_grid = SLR_param_grid, 
                      n_jobs=1, 
                      verbose=4,
                      scoring = "neg_mean_squared_error",
                      cv = 3,
                      return_train_score=True)

SV_search = GridSearchCV(estimator = SV, 
                      param_grid = SV_param_grid, 
                      n_jobs=1, 
                      verbose=4,
                      scoring = "neg_mean_squared_error",
                      cv = 3,
                      return_train_score=True)
KN_search = GridSearchCV(Kneighbors, 
                      KN_param_grid, 
                      n_jobs=1, 
                      verbose=4,
                      scoring = "neg_mean_squared_error",
                      cv = 3,
                      return_train_score=True)
Tree_search = GridSearchCV(Tree, 
                      Tree_param_grid, 
                      n_jobs=1, 
                      verbose=4,
                      scoring = "neg_mean_squared_error",
                      cv = 3,
                      return_train_score=True)
BR_search = GridSearchCV(BR,
                        BR_param_grid,
                        n_jobs=1,
                        verbose=4,
                        scoring = "neg_mean_squared_error",
                        cv = 3,
                        return_train_score=True)

# %%
# TRAINING THE MODELS

SLR_search.fit(X_train, y_train)
SV_search.fit(X_train,y_train)
KN_search.fit(X_train,y_train)
Tree_search.fit(X_train,y_train)
BR_search.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END regressor__positive=True;, score=(train=-515.184, test=-427.768) total time=   0.0s
# [CV 2/3] END regressor__positive=True;, score=(train=-510.925, test=-421.645) total time=   0.0s
# [CV 3/3] END regressor__positive=True;, score=(train=-393.974, test=-677.083) total time=   0.0s
# [CV 1/3] END regressor__positive=False;, score=(train=-490.450, test=-415.587) total time=   0.0s
# [CV 2/3] END regressor__positive=False;, score=(train=-486.214, test=-408.419) total time=   0.0s
# [CV 3/3] END regressor__positive=False;, score=(train=-364.732, test=-675.910) total time=   0.0s
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 1/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-519.533, test=-441.418) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-513.278, test=-430.884) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-388.368, test=-649.823) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-3072.714, test=-2917.879) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-3042.228, test=-3261.698) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-3131.418, test=-3088.450) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-3403.324, test=-3234.738) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-3351.006, test=-3597.382) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-3467.075, test=-3409.989) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-519.533, test=-441.418) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-513.278, test=-430.884) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-388.368, test=-649.823) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-1334.269, test=-1297.906) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-1370.479, test=-1400.056) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-1392.115, test=-1447.987) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-1309.367, test=-1248.271) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-1328.791, test=-1350.386) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-1361.838, test=-1426.181) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=linear;, score=(train=-519.533, test=-441.418) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=linear;, score=(train=-513.278, test=-430.884) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=linear;, score=(train=-388.368, test=-649.823) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3764.532, test=-3661.938) total time=   0.1s
# [CV 2/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3648.944, test=-4024.836) total time=   0.1s
# [CV 3/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3796.481, test=-3811.814) total time=   0.0s
# [CV 1/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-11918.344, test=-9831.403) total time=   0.0s
# [CV 2/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-11675.809, test=-10756.350) total time=   0.0s
# [CV 3/3] END regressor__C=1, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-11432.720, test=-11586.694) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-514.510, test=-430.118) total time=   0.1s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-512.318, test=-429.516) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-377.441, test=-676.922) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-1349.708, test=-1290.254) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-1386.908, test=-1418.053) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-1405.380, test=-1463.110) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-2098.704, test=-1991.697) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-2120.656, test=-2243.875) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-2161.510, test=-2168.576) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-514.510, test=-430.118) total time=   0.1s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-512.318, test=-429.516) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-377.441, test=-676.922) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-542.506, test=-530.777) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-558.779, test=-459.542) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-455.199, test=-648.795) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-629.717, test=-588.005) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-643.892, test=-572.830) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-565.576, test=-736.914) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=linear;, score=(train=-514.510, test=-430.118) total time=   0.1s
# [CV 2/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=linear;, score=(train=-512.318, test=-429.516) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=linear;, score=(train=-377.441, test=-676.922) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3268.294, test=-3497.431) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3176.188, test=-3886.190) total time=   0.1s
# [CV 3/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-3326.174, test=-3669.559) total time=   0.0s
# [CV 1/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-275625.330, test=-249619.533) total time=   0.0s
# [CV 2/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-291406.403, test=-278416.324) total time=   0.0s
# [CV 3/3] END regressor__C=5, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-259958.080, test=-255606.871) total time=   0.0s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-514.846, test=-427.007) total time=   0.1s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-513.191, test=-433.161) total time=   0.1s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=linear;, score=(train=-377.966, test=-680.052) total time=   0.1s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-820.381, test=-781.847) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-855.793, test=-815.403) total time=   0.0s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=rbf;, score=(train=-796.900, test=-920.343) total time=   0.0s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-1277.773, test=-1219.237) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-1305.305, test=-1326.274) total time=   0.0s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.001, regressor__kernel=sigmoid;, score=(train=-1331.824, test=-1397.907) total time=   0.0s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-514.846, test=-427.007) total time=   0.1s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-513.191, test=-433.161) total time=   0.1s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=linear;, score=(train=-377.966, test=-680.052) total time=   0.1s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-484.133, test=-453.573) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-494.289, test=-388.316) total time=   0.0s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=rbf;, score=(train=-374.852, test=-607.014) total time=   0.0s
# [CV 1/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-607.592, test=-553.315) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-601.670, test=-521.785) total time=   0.0s
# [CV 3/3] END regressor__C=10, regressor__gamma=0.01, regressor__kernel=sigmoid;, score=(train=-511.541, test=-697.449) total time=   0.0s
# [CV 1/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=linear;, score=(train=-514.846, test=-427.007) total time=   0.1s
# [CV 2/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=linear;, score=(train=-513.191, test=-433.161) total time=   0.1s
# [CV 3/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=linear;, score=(train=-377.966, test=-680.052) total time=   0.1s
# [CV 1/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-2759.558, test=-3324.195) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-2668.471, test=-3702.245) total time=   0.1s
# [CV 3/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=rbf;, score=(train=-2804.765, test=-3483.894) total time=   0.1s
# [CV 1/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-1105377.041, test=-989274.228) total time=   0.0s
# [CV 2/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-1151956.111, test=-1095902.914) total time=   0.0s
# [CV 3/3] END regressor__C=10, regressor__gamma=1, regressor__kernel=sigmoid;, score=(train=-1016635.303, test=-987777.837) total time=   0.0s
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END regressor__n_neighbors=2;, score=(train=-84.460, test=-272.431) total time=   0.1s
# [CV 2/3] END regressor__n_neighbors=2;, score=(train=-79.838, test=-488.136) total time=   0.0s
# [CV 3/3] END regressor__n_neighbors=2;, score=(train=-80.471, test=-331.940) total time=   0.1s
# [CV 1/3] END regressor__n_neighbors=3;, score=(train=-157.174, test=-331.166) total time=   0.1s
# [CV 2/3] END regressor__n_neighbors=3;, score=(train=-124.965, test=-437.414) total time=   0.1s
# [CV 3/3] END regressor__n_neighbors=3;, score=(train=-128.541, test=-431.987) total time=   0.1s
# [CV 1/3] END regressor__n_neighbors=5;, score=(train=-239.001, test=-446.651) total time=   0.1s
# [CV 2/3] END regressor__n_neighbors=5;, score=(train=-218.138, test=-432.068) total time=   0.1s
# [CV 3/3] END regressor__n_neighbors=5;, score=(train=-225.014, test=-505.082) total time=   0.1s
# [CV 1/3] END regressor__n_neighbors=7;, score=(train=-324.433, test=-518.509) total time=   0.1s
# [CV 2/3] END regressor__n_neighbors=7;, score=(train=-313.679, test=-405.816) total time=   0.1s
# [CV 3/3] END regressor__n_neighbors=7;, score=(train=-281.839, test=-547.479) total time=   0.1s
# [CV 1/3] END regressor__n_neighbors=10;, score=(train=-399.944, test=-601.381) total time=   0.1s
# [CV 2/3] END regressor__n_neighbors=10;, score=(train=-398.327, test=-446.649) total time=   0.1s
# [CV 3/3] END regressor__n_neighbors=10;, score=(train=-343.144, test=-605.151) total time=   0.1s
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-546.160, test=-483.411) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-553.673, test=-560.862) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-404.207, test=-860.310) total time=   0.0s
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-948.751, test=-936.680) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-874.957, test=-712.404) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-592.041, test=-897.973) total time=   0.0s
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-546.160, test=-483.411) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-553.673, test=-560.862) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-404.207, test=-860.310) total time=   0.0s
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-921.677, test=-763.938) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-792.680, test=-656.856) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-616.894, test=-1009.644) total time=   0.0s
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-546.160, test=-483.411) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-553.673, test=-560.862) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-404.207, test=-860.310) total time=   0.0s
# [CV 1/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-805.205, test=-792.542) total time=   0.0s
# [CV 2/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-782.845, test=-659.988) total time=   0.0s
# [CV 3/3] END regressor__max_depth=3, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-547.799, test=-899.701) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-233.988, test=-506.242) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-241.374, test=-580.942) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-234.508, test=-798.830) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-507.989, test=-484.925) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-475.610, test=-545.665) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-368.814, test=-718.945) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-285.616, test=-552.482) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-285.535, test=-520.008) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=best;, score=(train=-238.169, test=-794.213) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-480.396, test=-511.226) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-588.847, test=-549.543) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=5, regressor__splitter=random;, score=(train=-479.477, test=-985.918) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-356.710, test=-500.597) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-339.359, test=-499.136) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=best;, score=(train=-251.573, test=-782.728) total time=   0.0s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-631.888, test=-805.863) total time=   0.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-658.791, test=-585.519) total time=   0.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=10, regressor__splitter=random;, score=(train=-608.124, test=-841.595) total time=   0.0s
# [CV 1/3] END regressor__max_depth=7, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-93.096, test=-502.700) total time=   0.0s
# [CV 2/3] END regressor__max_depth=7, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-101.738, test=-597.955) total time=   0.0s
# [CV 3/3] END regressor__max_depth=7, regressor__min_samples_leaf=1, regressor__splitter=best;, score=(train=-85.987, test=-847.994) total time=   0.0s
# [CV 1/3] END regressor__max_depth=7, regressor__min_samples_leaf=1, regressor__splitter=random;, score=(train=-377.871, test=-467.499) total time=   0.0s
# [CV 2/3] END regressor__max_depth=7, regressor__min_samples_leaf=1, regressor

# [CV 1/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=10;, score=(train=-72.488, test=-275.579) total time=   0.1s
# [CV 2/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=10;, score=(train=-76.183, test=-276.226) total time=   0.1s
# [CV 3/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=10;, score=(train=-68.875, test=-548.113) total time=   0.1s
# [CV 1/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=15;, score=(train=-80.796, test=-311.344) total time=   0.1s
# [CV 2/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=15;, score=(train=-66.739, test=-288.348) total time=   0.1s
# [CV 3/3] END regressor__bootstrap=False, regressor__bootstrap_features=False, regressor__max_features=0.5, regressor__max_samples=0.6, regressor__n_estimators=15;, score=(train=-63.044, test=-523.900) total time=   0.1s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler()),
#                                                                                          ('missing_values',
#                                                                                           SimpleImputer())]),
#                                                                          ['Hour',
#                                                                           'TL1H80',
#                                                                           'TL2H80',
#                                                                           'TL3H80',
#                                                                           'TL4H80',
#                                                                           'TL5H80',
#                                                                           'TL6H80',
#                                                                           'TL7H80',
#                                                                           'TL8H80',
#                                                                           'TL9H80',
#                                                                           'TL10H80',
#                                                                           'WSL1H80',
#                                                                           'WSL2H80',
#                                                                           'WSL3H80',
#                                                                           'WSL4H80',
#                                                                           'WSL5H8...
#                                                                           'WDL7H80',
#                                                                           'WDL8H80',
#                                                                           'WDL9H80', ...])])),
#                                        ('regressor', BaggingRegressor())]),
#              n_jobs=1,
#              param_grid={'regressor__bootstrap': [True, False],
#                          'regressor__bootstrap_features': [True, False],
#                          'regressor__max_features': [0.3, 0.4, 0.5],
#                          'regressor__max_samples': [0.4, 0.5, 0.6],
#                          'regressor__n_estimators': [5, 10, 15]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=4)

# %%
# BEST MODELS

print('SLR:',SLR_search.best_params_,'(best)\n',
      SLR_search.best_estimator_.score(X_train, y_train),'(train score)\n',
      SLR_search.best_estimator_.score(X_test, y_test), '(test score)\n')
print('SV:',SV_search.best_params_,'(best)\n',
      SV_search.best_estimator_.score(X_train, y_train),'(train score)\n',
      SV_search.best_estimator_.score(X_test, y_test), '(test score)\n')
print('KNN:',KN_search.best_params_, '(best)\n',
      KN_search.best_estimator_.score(X_train, y_train),'(train score)\n',
      KN_search.best_estimator_.score(X_test, y_test), '(test score)\n',)
print('Tree:',Tree_search.best_params_, '(best)\n',
      Tree_search.best_estimator_.score(X_train, y_train), '(train score)\n',
      Tree_search.best_estimator_.score(X_test, y_test), '(test score)\n',)
print('BR:',BR_search.best_params_, '(best)\n',
      BR_search.best_estimator_.score(X_train, y_train), '(train score)\n',
     BR_search.best_estimator_.score(X_test, y_test), '(test score)\n')
# Out:
# SLR: {'regressor__positive': False} (best)
#  0.8727177201064644 (train score)
#  0.8868712204466241 (test score)
#
# SV: {'regressor__C': 10, 'regressor__gamma': 0.01, 'regressor__kernel': 'rbf'} (best)
#  0.879649872542506 (train score)
#  0.9053624539727857 (test score)
#
# KNN: {'regressor__n_neighbors': 2} (best)
#  0.9832214990775999 (train score)
#  0.950945674867764 (test score)
#
# Tree: {'regressor__max_depth': 7, 'regressor__min_samples_leaf': 10, 'regressor__splitter': 'best'} (best)
#  0.924526414533582 (train score)
#  0.9029092738847903 (test score)
#
# BR: {'regressor__bootstrap': False, 'regressor__bootstrap_features': False, 'regressor__max_features': 0.5, 'regressor__max_samples': 0.6, 'regressor__n_estimators': 10} (best)
#  0.9837812435406276 (train score)
#  0.9330628073743868 (test score)

# %%
def root_mean_squared_error(pred, true) -> float:
    
    return np.sqrt(mean_squared_error(true,pred))

# %%
# MEASSURING PERFORMANCE

# RMSE

SLR_RMSE_train = root_mean_squared_error(SLR_search.best_estimator_.predict(X_train), y_train)
SLR_RMSE_test = root_mean_squared_error(SLR_search.best_estimator_.predict(X_test), y_test)
print('RMSE Simple Linear Regression-model:\n',
      SLR_RMSE_train, '(train)\n',
      SLR_RMSE_test, '(test)\n')

SV_RMSE_train = root_mean_squared_error(SV_search.best_estimator_.predict(X_train), y_train)
SV_RMSE_test = root_mean_squared_error(SV_search.best_estimator_.predict(X_test), y_test)
print('RMSE SVR-model:\n',
      SV_RMSE_train, '(train)\n',
      SV_RMSE_test, '(test)\n')

KN_RMSE_train = root_mean_squared_error(KN_search.best_estimator_.predict(X_train), y_train)
KN_RMSE_test = root_mean_squared_error(KN_search.best_estimator_.predict(X_test), y_test)
print('RMSE KNN-model:\n',
      KN_RMSE_train, '(train)\n',
      KN_RMSE_test, '(test)\n')

Tree_RMSE_train = root_mean_squared_error(Tree_search.best_estimator_.predict(X_train), y_train)
Tree_RMSE_test = root_mean_squared_error(Tree_search.best_estimator_.predict(X_test), y_test)
print('RMSE Tree-model:\n',
      Tree_RMSE_train, '(train)\n',
      Tree_RMSE_test, '(test)\n')

BR_RMSE_train = root_mean_squared_error(BR_search.best_estimator_.predict(X_train), y_train)
BR_RMSE_test = root_mean_squared_error(BR_search.best_estimator_.predict(X_test), y_test)
print('RMSE BaggingRegression-model:\n',
      BR_RMSE_train, '(train)\n',
      BR_RMSE_test, '(test)\n')

# CV error with RMSE

SLR_cv_error = np.sqrt(-SLR_search.cv_results_['mean_test_score'].mean())
print('SVR CV error:', SLR_cv_error)

SV_cv_error = np.sqrt(-SV_search.cv_results_['mean_test_score'].mean())
print('SVR CV error:', SV_cv_error)

KN_cv_error = np.sqrt(-KN_search.cv_results_['mean_test_score'].mean())
print('KNN CV error:', KN_cv_error)

Tree_cv_error = np.sqrt(-Tree_search.cv_results_['mean_test_score'].mean())
print('Tree CV error:', Tree_cv_error)

BR_cv_error = np.sqrt(-BR_search.cv_results_['mean_test_score'].mean())
print('BR CV error:', BR_cv_error)
# Out:
# RMSE Simple Linear Regression-model:
#  21.344225369461938 (train)
#  19.994443226058717 (test)
#
# RMSE SVR-model:
#  20.75485493513342 (train)
#  18.287506745494547 (test)
#
# RMSE KNN-model:
#  7.7494878738374355 (train)
#  13.166229371402794 (test)
#
# RMSE Tree-model:
#  16.435916115088112 (train)
#  18.52301330400415 (test)
#
# RMSE BaggingRegression-model:
#  7.619126798504163 (train)
#  15.380006218966706 (test)
#
# SVR CV error: 22.458892445712923
# SVR CV error: 221.86378791838032
# KNN CV error: 21.294535246390435
# Tree CV error: 25.490772739266113
# BR CV error: 21.87923055808892

# %%
# BEST MODEL PREDICTIONS for TEST_INPUT

#!! We consider the best model to be KNN for Regression

model = KN_search.best_estimator_

prediction = pd.DataFrame(model.predict(final_test_df))
prediction.to_csv("AndresJavierPablo.csv" , sep=" ", header=False, index=False)
